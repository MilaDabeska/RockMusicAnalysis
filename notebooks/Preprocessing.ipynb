# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
dataset=pd.read_csv("../data/history-of-rock-spotify.csv")
dataset
# Out:
#       index                                          name  \
# 0         0                       Smells Like Teen Spirit
# 1         1                 Stairway to Heaven - Remaster
# 2         2           Bohemian Rhapsody - Remastered 2011
# 3         3                     Imagine - Remastered 2010
# 4         4  (I Can't Get No) Satisfaction - Mono Version
# ...     ...                                           ...
# 5479   5479                              I'm In Your Mind
# 5480   5480                                    Cellophane
# 5481   5481                                     Hot Water
# 5482   5482           Vitamin C - 2004 Remastered Version
# 5483   5483                                             ~
#
#                                 artist  release_date    length  popularity  \
# 0                              Nirvana          1991  5.032000          74
# 1                         Led Zeppelin          1971  8.047167          78
# ...

# %% [markdown]
# &nbsp;

# %%
rows, columns = dataset.shape
print(f'Редици: {rows}\nКолони: {columns}')
# Out:
# Редици: 5484
# Колони: 18

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5484 entries, 0 to 5483
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   index             5484 non-null   int64
#  1   name              5484 non-null   object
#  2   artist            5484 non-null   object
#  3   release_date      5484 non-null   int64
#  4   length            5484 non-null   float64
#  5   popularity        5484 non-null   int64
#  6   danceability      5484 non-null   float64
#  7   acousticness      5484 non-null   float64
#  8   danceability.1    5484 non-null   float64
#  9   energy            5484 non-null   float64
#  10  instrumentalness  5484 non-null   float64
#  11  key               5484 non-null   int64
#  12  liveness          5484 non-null   float64
#  13  loudness          5484 non-null   float64
#  14  speechiness       5484 non-null   float64
#  15  tempo             5484 non-null   float64
# ...

# %% [markdown]
# &nbsp;

# %%
dataset['artist'].describe()
# Out:
# count                5484
# unique               1738
# top       Various Artists
# freq                  116
# Name: artist, dtype: object

# %%
dataset[dataset['artist'] == 'Various Artists'].head()
# Out:
#      index                                               name  \
# 163    163                                        Buddy Holly
# 227    227               No Woman, No Cry (Arr. Kanneh-Mason)
# 229    229                                         Proud Mary
# 466    466  I Don't Want to Miss a Thing - From "Armageddo...
# 470    470                   Bizarre Love Triangle - 7" Remix
#
#               artist  release_date    length  popularity  danceability  \
# 163  Various Artists          2020  2.682883           4         0.520
# 227  Various Artists          2020  2.433633           4         0.290
# 229  Various Artists          2020  3.079767          12         0.673
# 466  Various Artists          1998  4.979333          76         0.383
# 470  Various Artists          2020  3.752883           5         0.670
#
#      acousticness  danceability.1  energy  instrumentalness  key  liveness  \
# 163      0.000572           0.520  0.9120          0.000378    8    0.0554
# ...

# %%
dataset = dataset.drop(dataset[dataset['artist'] == 'Various Artists'].index)

# %% [markdown]
# &nbsp;

# %%
dataset.drop(['index', 'danceability.1'], axis=1, inplace = True)
dataset.head()
# Out:
#                                            name              artist  \
# 0                       Smells Like Teen Spirit             Nirvana
# 1                 Stairway to Heaven - Remaster        Led Zeppelin
# 2           Bohemian Rhapsody - Remastered 2011               Queen
# 3                     Imagine - Remastered 2010         John Lennon
# 4  (I Can't Get No) Satisfaction - Mono Version  The Rolling Stones
#
#    release_date    length  popularity  danceability  acousticness  energy  \
# 0          1991  5.032000          74         0.502      0.000025   0.912
# 1          1971  8.047167          78         0.338      0.580000   0.340
# 2          1975  5.905333          74         0.392      0.288000   0.402
# 3          1971  3.131100          77         0.547      0.907000   0.257
# 4          1965  3.713550          77         0.723      0.038300   0.863
#
#    instrumentalness  key  liveness  loudness  speechiness    tempo  \
# ...

# %%
rows, columns = dataset.shape
print(f'Редици: {rows}\nКолони: {columns}')
# Out:
# Редици: 5368
# Колони: 16

# %% [markdown]
# &nbsp;

# %%
dataset.rename(columns = {'length' : 'duration'}, inplace = True)

# %%
dataset['duration'] = dataset['duration'].round(decimals = 2)

# %%
dataset.head(3)
# Out:
#                                   name        artist  release_date  duration  \
# 0              Smells Like Teen Spirit       Nirvana          1991      5.03
# 1        Stairway to Heaven - Remaster  Led Zeppelin          1971      8.05
# 2  Bohemian Rhapsody - Remastered 2011         Queen          1975      5.91
#
#    popularity  danceability  acousticness  energy  instrumentalness  key  \
# 0          74         0.502      0.000025   0.912          0.000173    1
# 1          78         0.338      0.580000   0.340          0.003200    9
# 2          74         0.392      0.288000   0.402          0.000000    0
#
#    liveness  loudness  speechiness    tempo  time_signature  valence
# 0     0.106    -4.556       0.0564  116.761               4    0.720
# 1     0.116   -12.049       0.0339   82.433               4    0.197
# 2     0.243    -9.961       0.0536  143.883               4    0.228

# %% [markdown]
# &nbsp;

# %%
dataset['hit'] = ''

# %%
dataset['hit'] = pd.qcut(dataset['popularity'], q=2, labels=[0, 1]) 
dataset[['hit']].head()
# Out:
#   hit
# 0   1
# 1   1
# 2   1
# 3   1
# 4   1

# %%
dataset.head()
# Out:
#                                            name              artist  \
# 0                       Smells Like Teen Spirit             Nirvana
# 1                 Stairway to Heaven - Remaster        Led Zeppelin
# 2           Bohemian Rhapsody - Remastered 2011               Queen
# 3                     Imagine - Remastered 2010         John Lennon
# 4  (I Can't Get No) Satisfaction - Mono Version  The Rolling Stones
#
#    release_date  duration  popularity  danceability  acousticness  energy  \
# 0          1991      5.03          74         0.502      0.000025   0.912
# 1          1971      8.05          78         0.338      0.580000   0.340
# 2          1975      5.91          74         0.392      0.288000   0.402
# 3          1971      3.13          77         0.547      0.907000   0.257
# 4          1965      3.71          77         0.723      0.038300   0.863
#
#    instrumentalness  key  liveness  loudness  speechiness    tempo  \
# ...

# %%
target_v = dataset['hit'].value_counts(normalize=True).round(3)
target_v
# Out:
# 0    0.513
# 1    0.487
# Name: hit, dtype: float64

# %%
sns.barplot(x=target_v.index, y=target_v, palette="BrBG")
# Out:
# <AxesSubplot:ylabel='hit'>

# %%
dataset.to_csv('../data/rock_music.csv', index=False)
