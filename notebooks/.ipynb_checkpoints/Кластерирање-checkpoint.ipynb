# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from sklearn import metrics
from sklearn.neighbors import NearestNeighbors
from scipy.cluster.hierarchy import dendrogram, linkage, cut_tree
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split, cross_val_predict, cross_val_score, KFold, GridSearchCV
from sklearn.metrics import silhouette_score, calinski_harabasz_score, silhouette_samples
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer, silhouette_visualizer
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
from kneed import KneeLocator
import warnings
warnings.filterwarnings("ignore")

# %%
dataset=pd.read_csv('data/rock_music.csv')
dataset.set_index('name', inplace=True)
dataset
# Out:
#                                                                         artist  \
# name
# Smells Like Teen Spirit                                                Nirvana
# Stairway to Heaven - Remaster                                     Led Zeppelin
# Bohemian Rhapsody - Remastered 2011                                      Queen
# Imagine - Remastered 2010                                          John Lennon
# (I Can't Get No) Satisfaction - Mono Version                The Rolling Stones
# ...                                                                        ...
# I'm In Your Mind                              King Gizzard & The Lizard Wizard
# Cellophane                                    King Gizzard & The Lizard Wizard
# Hot Water                                     King Gizzard & The Lizard Wizard
# Vitamin C - 2004 Remastered Version                                        CAN
# ~                                                                 Touché Amoré
#
#                                               release_date  duration  \
# name
# Smells Like Teen Spirit                               1991      5.03
# Stairway to Heaven - Remaster                         1971      8.05
# Bohemian Rhapsody - Remastered 2011                   1975      5.91
# Imagine - Remastered 2010                             1971      3.13
# (I Can't Get No) Satisfaction - Mono Version          1965      3.71
# ...                                                    ...       ...
# I'm In Your Mind                                      2014      3.56
# Cellophane                                            2014      3.18
# Hot Water                                             2014      3.40
# Vitamin C - 2004 Remastered Version                   1972      3.57
# ~                                                     2011      1.49
#
#                                               popularity  danceability  \
# name
# Smells Like Teen Spirit                               74         0.502
# Stairway to Heaven - Remaster                         78         0.338
# Bohemian Rhapsody - Remastered 2011                   74         0.392
# Imagine - Remastered 2010                             77         0.547
# (I Can't Get No) Satisfaction - Mono Version          77         0.723
# ...                                                  ...           ...
# I'm In Your Mind                                      47         0.296
# Cellophane                                            44         0.432
# Hot Water                                             40         0.627
# Vitamin C - 2004 Remastered Version                   52         0.643
# ~                                                      0         0.222
#
#                                               acousticness  energy  \
# name
# Smells Like Teen Spirit                           0.000025   0.912
# Stairway to Heaven - Remaster                     0.580000   0.340
# Bohemian Rhapsody - Remastered 2011               0.288000   0.402
# Imagine - Remastered 2010                         0.907000   0.257
# (I Can't Get No) Satisfaction - Mono Version      0.038300   0.863
# ...                                                    ...     ...
# I'm In Your Mind                                  0.005910   0.776
# Cellophane                                        0.002130   0.887
# Hot Water                                         0.860000   0.609
# Vitamin C - 2004 Remastered Version               0.006690   0.644
# ~                                                 0.000258   0.959
#
#                                               instrumentalness  key  liveness  \
# name
# Smells Like Teen Spirit                               0.000173    1    0.1060
# Stairway to Heaven - Remaster                         0.003200    9    0.1160
# Bohemian Rhapsody - Remastered 2011                   0.000000    0    0.2430
# Imagine - Remastered 2010                             0.183000    0    0.0935
# (I Can't Get No) Satisfaction - Mono Version          0.031700    2    0.1280
# ...                                                        ...  ...       ...
# I'm In Your Mind                                      0.801000    6    0.5970
# Cellophane                                            0.916000    7    0.1200
# Hot Water                                             0.890000    9    0.1160
# Vitamin C - 2004 Remastered Version                   0.673000    4    0.1620
# ~                                                     0.000275    6    0.1540
#
#                                               loudness  speechiness    tempo  \
# name
# Smells Like Teen Spirit                         -4.556       0.0564  116.761
# Stairway to Heaven - Remaster                  -12.049       0.0339   82.433
# Bohemian Rhapsody - Remastered 2011             -9.961       0.0536  143.883
# Imagine - Remastered 2010                      -12.358       0.0252   75.752
# (I Can't Get No) Satisfaction - Mono Version    -7.890       0.0338  136.302
# ...                                                ...          ...      ...
# I'm In Your Mind                                -5.630       0.0597   93.481
# Cellophane                                      -6.175       0.1230   92.965
# Hot Water                                       -9.387       0.0332   86.861
# Vitamin C - 2004 Remastered Version            -12.615       0.0462  117.225
# ~                                               -5.134       0.2080  161.693
#
#                                               time_signature  valence  hit
# name
# Smells Like Teen Spirit                                    4    0.720    1
# Stairway to Heaven - Remaster                              4    0.197    1
# Bohemian Rhapsody - Remastered 2011                        4    0.228    1
# Imagine - Remastered 2010                                  4    0.169    1
# (I Can't Get No) Satisfaction - Mono Version               4    0.931    1
# ...                                                      ...      ...  ...
# I'm In Your Mind                                           4    0.406    0
# Cellophane                                                 4    0.357    0
# Hot Water                                                  4    0.734    0
# Vitamin C - 2004 Remastered Version                        4    0.853    0
# ~                                                          4    0.128    0
#
# [5368 rows x 16 columns]

# %% [markdown]
# Бидејќи сите алгоритми за кластерирање можат да работат само со нумерички податоци.

# %%
dataset.drop(['artist', 'release_date', 'hit'], axis=1, inplace=True)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(dataset.corr(), annot=True)
plt.show()

# %% [markdown]
# Променливите energy и loudness имаат висока позитивна корелација од 0.76. Тие носат многу исти информации, можеби треба да отфрлиме една за да не го пристрасуваме(bias) кластерирањето кон тој атрибут.

# %%
dataset.drop(['loudness'], axis=1, inplace=True)

# %%
scaler = StandardScaler()
dataset[dataset.columns] = scaler.fit_transform(dataset)
dataset
# Out:
#                                               duration  popularity  \
# name
# Smells Like Teen Spirit                       0.585096    1.428054
# Stairway to Heaven - Remaster                 2.598017    1.664477
# Bohemian Rhapsody - Remastered 2011           1.171643    1.428054
# Imagine - Remastered 2010                    -0.681311    1.605371
# (I Can't Get No) Satisfaction - Mono Version -0.294724    1.605371
# ...                                                ...         ...
# I'm In Your Mind                             -0.394703   -0.167804
# Cellophane                                   -0.647985   -0.345122
# Hot Water                                    -0.501348   -0.581545
# Vitamin C - 2004 Remastered Version          -0.388038    0.127725
# ~                                            -1.774420   -2.945779
#
#                                               danceability  acousticness  \
# name
# Smells Like Teen Spirit                          -0.058417     -0.710999
# Stairway to Heaven - Remaster                    -1.168076      1.690857
# Bohemian Rhapsody - Remastered 2011              -0.802700      0.481593
# Imagine - Remastered 2010                         0.246063      3.045067
# (I Can't Get No) Satisfaction - Mono Version      1.436916     -0.552493
# ...                                                    ...           ...
# I'm In Your Mind                                 -1.452256     -0.686630
# Cellophane                                       -0.532052     -0.702284
# Hot Water                                         0.787360      2.850425
# Vitamin C - 2004 Remastered Version               0.895619     -0.683400
# ~                                                -1.952956     -0.710037
#
#                                                 energy  instrumentalness  \
# name
# Smells Like Teen Spirit                       0.955291         -0.387938
# Stairway to Heaven - Remaster                -1.838501         -0.372465
# Bohemian Rhapsody - Remastered 2011          -1.535678         -0.388823
# Imagine - Remastered 2010                    -2.243894          0.546644
# (I Can't Get No) Satisfaction - Mono Version  0.715962         -0.226777
# ...                                                ...               ...
# I'm In Your Mind                              0.291033          3.705760
# Cellophane                                    0.833185          4.293622
# Hot Water                                    -0.524637          4.160714
# Vitamin C - 2004 Remastered Version          -0.353689          3.051445
# ~                                             1.184851         -0.387417
#
#                                                    key  liveness  speechiness  \
# name
# Smells Like Teen Spirit                      -1.203696 -0.547652    -0.032631
# Stairway to Heaven - Remaster                 1.089018 -0.491126    -0.510224
# Bohemian Rhapsody - Remastered 2011          -1.490285  0.226760    -0.092065
# Imagine - Remastered 2010                    -1.490285 -0.618310    -0.694893
# (I Can't Get No) Satisfaction - Mono Version -0.917107 -0.423294    -0.512346
# ...                                                ...       ...          ...
# I'm In Your Mind                              0.229250  2.227795     0.037416
# Cellophane                                    0.515839 -0.468515     1.381043
# Hot Water                                     1.089018 -0.491126    -0.525082
# Vitamin C - 2004 Remastered Version          -0.343928 -0.231104    -0.249140
# ~                                             0.229250 -0.276325     3.185281
#
#                                                  tempo  time_signature  \
# name
# Smells Like Teen Spirit                      -0.305184        0.182219
# Stairway to Heaven - Remaster                -1.515630        0.182219
# Bohemian Rhapsody - Remastered 2011           0.651171        0.182219
# Imagine - Remastered 2010                    -1.751211        0.182219
# (I Can't Get No) Satisfaction - Mono Version  0.383855        0.182219
# ...                                                ...             ...
# I'm In Your Mind                             -1.126065        0.182219
# Cellophane                                   -1.144259        0.182219
# Hot Water                                    -1.359494        0.182219
# Vitamin C - 2004 Remastered Version          -0.288823        0.182219
# ~                                             1.279173        0.182219
#
#                                                valence
# name
# Smells Like Teen Spirit                       0.678842
# Stairway to Heaven - Remaster                -1.486855
# Bohemian Rhapsody - Remastered 2011          -1.358487
# Imagine - Remastered 2010                    -1.602800
# (I Can't Get No) Satisfaction - Mono Version  1.552575
# ...                                                ...
# I'm In Your Mind                             -0.621404
# Cellophane                                   -0.824309
# Hot Water                                     0.736815
# Vitamin C - 2004 Remastered Version           1.229584
# ~                                            -1.772578
#
# [5368 rows x 12 columns]

# %% [markdown]
# &nbsp;

# %%
pca = PCA(n_components=2)
dataset_pca = pca.fit(dataset).transform(dataset)

# %%
plt.figure(figsize=(7, 7))
sns.scatterplot(x = dataset_pca[:, 0], y = dataset_pca[:, 1])
plt.show()

# %% [markdown]
# &nbsp;

# %% [markdown]
# ## K-Means

# %%
numClusters = range(2, 10)
SSE = []
silhouette_coefficients = []

for k in numClusters:
    kmeans = KMeans(n_clusters=k, max_iter=150, random_state=0)
    kmeans.fit(dataset_pca)
    SSE.append(kmeans.inertia_)
    
    if k<=1:
        continue;
    score = silhouette_score(dataset_pca, kmeans.labels_)
    silhouette_coefficients.append(score)
    
plt.plot(numClusters, SSE)
plt.xlabel('Number Of Clusters')
plt.ylabel('SSE')
# Out:
# Text(0, 0.5, 'SSE')

# %%
kl = KneeLocator(range(2, 10), SSE, curve="convex", direction="decreasing")
kl.elbow
# Out:
# 4

# %%
silhouette_visualizer(KMeans(4, random_state=42), dataset_pca, colors='yellowbrick')
# Out:
# SilhouetteVisualizer(ax=<AxesSubplot:title={'center':'Silhouette Plot of KMeans Clustering for 5368 Samples in 4 Centers'}, xlabel='silhouette coefficient values', ylabel='cluster label'>,
#                      colors='yellowbrick',
#                      estimator=KMeans(n_clusters=4, random_state=42))

# %%
data = pd.DataFrame(dataset_pca)

# %%
data
# Out:
#              0         1
# 0     0.137580 -0.876625
# 1    -1.830941  3.191868
# 2    -0.467884  2.111571
# 3    -3.679806  2.386564
# 4    -0.793700 -2.212386
# ...        ...       ...
# 5363  1.788885  1.526260
# 5364  1.505716  0.716458
# 5365 -2.187711  0.858584
# 5366 -0.446053 -0.678385
# 5367  3.773775  0.325298
#
# [5368 rows x 2 columns]

# %%
range_n_clusters = [2, 3, 4, 5]

for n_clusters in range_n_clusters:
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)
    ax1.set_xlim([-0.1, 1])
    ax1.set_ylim([0, len(data) + (n_clusters + 1) * 10])

    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(data)

    silhouette_avg = silhouette_score(data, cluster_labels)
    print("For n_clusters =",n_clusters,
        "The average silhouette_score is :",silhouette_avg)

    sample_silhouette_values = silhouette_samples(dataset_pca, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        ith_cluster_silhouette_values = sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(
            np.arange(y_lower, y_upper),
            0,
            ith_cluster_silhouette_values,
            facecolor=color,
            edgecolor=color,
            alpha=0.7,
        )

        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        y_lower = y_upper + 10  

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
    ax2.scatter(
        data[0], data[1], marker=".", s=30, lw=0, alpha=0.7, c=colors, edgecolor="k"
    )

    centers = clusterer.cluster_centers_

    ax2.scatter(
        centers[:, 0],
        centers[:, 1],
        marker="o",
        c="white",
        alpha=1,
        s=200,
        edgecolor="k",
    )

    for i, c in enumerate(centers):
        ax2.scatter(c[0], c[1], marker="$%d$" % i, alpha=1, s=50, edgecolor="k")

    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("Feature space for the 1st feature")
    ax2.set_ylabel("Feature space for the 2nd feature")

plt.show()
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.3254103082071613
# For n_clusters = 3 The average silhouette_score is : 0.37640260253079233
# For n_clusters = 4 The average silhouette_score is : 0.321247139968634
# For n_clusters = 5 The average silhouette_score is : 0.3312852735877682

# %%
def k_means(data, n_clusters):
    k_means = KMeans(n_clusters=n_clusters, max_iter=50, random_state=1)
    k_means.fit(data)
    labels = k_means.labels_
    centroids = k_means.cluster_centers_
    pd.DataFrame(centroids)
    
    sns.scatterplot(x=data[:,0], y=data[:,1], hue=labels, c=labels, ax=plt.gca())
    sns.scatterplot(x=centroids[:,0], y=centroids[:,1], marker="*", color="m", s=500)
    plt.show()

# %%
k_means(dataset_pca, 4)

# %%
silhouette_coefficients[2]
# Out:
# 0.32069984088143283

# %% [markdown]
# &nbsp;

# %% [markdown]
# ## Hierarchical (Agglomerative)

# %%
ac = AgglomerativeClustering(n_clusters=4).fit(dataset_pca)
sns.scatterplot(x=dataset_pca[:,0], y=dataset_pca[:,1], hue=ac.labels_)
plt.show()

# %% [markdown]
# &nbsp;

# %% [markdown]
# Хиерархиско групирање на првите 10 песни

# %%
Z = linkage(dataset_pca[:10], 'ward')
fig = plt.figure(figsize=(15, 10))
plt.title('Dendrogram Ward Method')
plt.xlabel('Song')
plt.xticks(ticks = range(0, 10), labels=dataset.index[:10].tolist(), rotation=90)
plt.ylabel('distance')
dendrogram(Z, leaf_rotation=90., color_threshold=4, leaf_font_size=8., ax=plt.gca(), labels=dataset.index[:10].tolist())
plt.show()

# %%
linkage_types = ['ward', 'complete', 'average', 'single']

for link_type in linkage_types:
    Z = linkage(dataset_pca[:10], link_type)
    plt.figure(figsize=(10, 5))
    plt.title('Hierarchical Clustering Dendrogram')
    plt.xlabel('sample index')
    plt.ylabel('distance')
    dendrogram(Z, leaf_rotation=90., leaf_font_size=8.);
    plt.show();
    
plt.figure(figsize=(10, 5))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('sample index')
plt.ylabel('distance')
dendrogram(Z, leaf_rotation=90., leaf_font_size=8., truncate_mode='lastp');

# %% [markdown]
# &nbsp;

# %% [markdown]
# ## DBSCAN

# %%
neighbors = [2, 3, 4, 5]
distances = []

for i in neighbors:
    neigh = NearestNeighbors(n_neighbors=i)
    nbrs = neigh.fit(dataset_pca)
    distances, indices = nbrs.kneighbors(dataset_pca)
    distances = np.sort(distances, axis=0)
    distances = distances[:, i-1]

    plt.figure(figsize=(5, 3))
    plt.plot(distances);
    plt.title('Distances to the ' + str(i) + ' nearest neighbor')
    plt.show()

# %%
db = DBSCAN(eps=0.1, min_samples=2).fit(dataset_pca)

# %%
sns.scatterplot(x=dataset_pca[:,0], y=dataset_pca[:,1], hue=db.labels_)
plt.show()
