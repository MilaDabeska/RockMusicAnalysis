# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.preprocessing import PolynomialFeatures, LabelEncoder, StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LassoCV
from sklearn.model_selection import KFold
from yellowbrick.regressor import ResidualsPlot
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
import statsmodels.api as sm
from sklearn import metrics
import pandas as pd
import numpy as np
from scipy import stats
from operator import sub
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
dataset = pd.read_csv('../data/rock_music.csv')
dataset.set_index('name', inplace=True)
dataset
# Out:
#                                                                         artist  \
# name
# Smells Like Teen Spirit                                                Nirvana
# Stairway to Heaven - Remaster                                     Led Zeppelin
# Bohemian Rhapsody - Remastered 2011                                      Queen
# Imagine - Remastered 2010                                          John Lennon
# (I Can't Get No) Satisfaction - Mono Version                The Rolling Stones
# ...                                                                        ...
# I'm In Your Mind                              King Gizzard & The Lizard Wizard
# Cellophane                                    King Gizzard & The Lizard Wizard
# Hot Water                                     King Gizzard & The Lizard Wizard
# Vitamin C - 2004 Remastered Version                                        CAN
# ~                                                                 Touché Amoré
#
#                                               release_date  duration  \
# name
# Smells Like Teen Spirit                               1991      5.03
# Stairway to Heaven - Remaster                         1971      8.05
# Bohemian Rhapsody - Remastered 2011                   1975      5.91
# Imagine - Remastered 2010                             1971      3.13
# (I Can't Get No) Satisfaction - Mono Version          1965      3.71
# ...                                                    ...       ...
# I'm In Your Mind                                      2014      3.56
# Cellophane                                            2014      3.18
# Hot Water                                             2014      3.40
# Vitamin C - 2004 Remastered Version                   1972      3.57
# ~                                                     2011      1.49
#
#                                               popularity  danceability  \
# name
# Smells Like Teen Spirit                               74         0.502
# Stairway to Heaven - Remaster                         78         0.338
# Bohemian Rhapsody - Remastered 2011                   74         0.392
# Imagine - Remastered 2010                             77         0.547
# (I Can't Get No) Satisfaction - Mono Version          77         0.723
# ...                                                  ...           ...
# I'm In Your Mind                                      47         0.296
# Cellophane                                            44         0.432
# Hot Water                                             40         0.627
# Vitamin C - 2004 Remastered Version                   52         0.643
# ~                                                      0         0.222
#
#                                               acousticness  energy  \
# name
# Smells Like Teen Spirit                           0.000025   0.912
# Stairway to Heaven - Remaster                     0.580000   0.340
# Bohemian Rhapsody - Remastered 2011               0.288000   0.402
# Imagine - Remastered 2010                         0.907000   0.257
# (I Can't Get No) Satisfaction - Mono Version      0.038300   0.863
# ...                                                    ...     ...
# I'm In Your Mind                                  0.005910   0.776
# Cellophane                                        0.002130   0.887
# Hot Water                                         0.860000   0.609
# Vitamin C - 2004 Remastered Version               0.006690   0.644
# ~                                                 0.000258   0.959
#
#                                               instrumentalness  key  liveness  \
# name
# Smells Like Teen Spirit                               0.000173    1    0.1060
# Stairway to Heaven - Remaster                         0.003200    9    0.1160
# Bohemian Rhapsody - Remastered 2011                   0.000000    0    0.2430
# Imagine - Remastered 2010                             0.183000    0    0.0935
# (I Can't Get No) Satisfaction - Mono Version          0.031700    2    0.1280
# ...                                                        ...  ...       ...
# I'm In Your Mind                                      0.801000    6    0.5970
# Cellophane                                            0.916000    7    0.1200
# Hot Water                                             0.890000    9    0.1160
# Vitamin C - 2004 Remastered Version                   0.673000    4    0.1620
# ~                                                     0.000275    6    0.1540
#
#                                               loudness  speechiness    tempo  \
# name
# Smells Like Teen Spirit                         -4.556       0.0564  116.761
# Stairway to Heaven - Remaster                  -12.049       0.0339   82.433
# Bohemian Rhapsody - Remastered 2011             -9.961       0.0536  143.883
# Imagine - Remastered 2010                      -12.358       0.0252   75.752
# (I Can't Get No) Satisfaction - Mono Version    -7.890       0.0338  136.302
# ...                                                ...          ...      ...
# I'm In Your Mind                                -5.630       0.0597   93.481
# Cellophane                                      -6.175       0.1230   92.965
# Hot Water                                       -9.387       0.0332   86.861
# Vitamin C - 2004 Remastered Version            -12.615       0.0462  117.225
# ~                                               -5.134       0.2080  161.693
#
#                                               time_signature  valence  hit
# name
# Smells Like Teen Spirit                                    4    0.720    1
# Stairway to Heaven - Remaster                              4    0.197    1
# Bohemian Rhapsody - Remastered 2011                        4    0.228    1
# Imagine - Remastered 2010                                  4    0.169    1
# (I Can't Get No) Satisfaction - Mono Version               4    0.931    1
# ...                                                      ...      ...  ...
# I'm In Your Mind                                           4    0.406    0
# Cellophane                                                 4    0.357    0
# Hot Water                                                  4    0.734    0
# Vitamin C - 2004 Remastered Version                        4    0.853    0
# ~                                                          4    0.128    0
#
# [5368 rows x 16 columns]

# %%
dataset = dataset.apply(LabelEncoder().fit_transform).drop(['hit'], axis=1)
dataset.head(3)
# Out:
#                                      artist  release_date  duration  \
# name
# Smells Like Teen Spirit                 942            35       343
# Stairway to Heaven - Remaster           772            15       580
# Bohemian Rhapsody - Remastered 2011    1045            19       430
#
#                                      popularity  danceability  acousticness  \
# name
# Smells Like Teen Spirit                      74           362           100
# Stairway to Heaven - Remaster                78           198          2328
# Bohemian Rhapsody - Remastered 2011          74           252          2067
#
#                                      energy  instrumentalness  key  liveness  \
# name
# Smells Like Teen Spirit                 748               908    1       594
# Stairway to Heaven - Remaster           182              1451    9       604
# Bohemian Rhapsody - Remastered 2011     239                 0    0       731
#
#                                      loudness  speechiness  tempo  \
# name
# Smells Like Teen Spirit                  3567          331   2037
# Stairway to Heaven - Remaster             672          106    312
# Bohemian Rhapsody - Remastered 2011      1226          303   3919
#
#                                      time_signature  valence
# name
# Smells Like Teen Spirit                           2      706
# Stairway to Heaven - Remaster                     2      183
# Bohemian Rhapsody - Remastered 2011               2      214

# %%
plt.figure(figsize=(10,7))
sns.distplot(dataset['popularity'], kde=True, rug=True)
plt.title('Target variable distribution')
plt.show()

# %%
X = dataset.drop(['popularity'], axis = 1)
Y = dataset['popularity']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
X_columns = X.columns

# %%
scaler = StandardScaler()
scaler.fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

X = scaler.transform(X)

# %%
plt.figure(figsize=(10,10))
sns.heatmap(dataset[dataset.columns.drop(['artist', 'release_date'])].corr(), annot=True, linewidth = .5)
plt.show()

# %%
plt.figure(figsize=(15,7))
plt.subplot(1,2,1)
sns.scatterplot(data=dataset.head(1000), x='energy', y='popularity', ax=plt.gca(), color='green')
plt.title('popularity x energy')
plt.subplot(1,2,2)
sns.scatterplot(data=dataset.head(1000), x='danceability', y='popularity', ax=plt.gca(), color='red')
plt.title('popularity x danceability')
plt.show()

# %% [markdown]
# &nbsp;

# %% [markdown]
# ## Linear Regression

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
coeff_lr = pd.DataFrame(lr.coef_, X_columns, columns=['Coefficient'])
coeff_lr
# Out:
#                   Coefficient
# artist              -0.121594
# release_date        -5.516281
# duration             0.867165
# danceability         2.179085
# acousticness        -0.488593
# energy              -2.029276
# instrumentalness    -1.216950
# key                  0.655680
# liveness            -1.318021
# loudness             3.761546
# speechiness         -0.813226
# tempo                0.257543
# time_signature      -0.040201
# valence             -1.242682

# %%
predictions = lr.predict(X_test)
plt.figure(figsize=(10,7))
plt.scatter(y_test, predictions)
plt.title('Predictions vs Actual')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()

# %%
sns.displot((y_test - predictions), bins=30, kde=True, color='crimson')
plt.show()

# %%
visualizer = ResidualsPlot(lr, hist=True, qqplot=False)
visualizer.fit(X_train, y_train)  
visualizer.score(X_test, y_test)  
visualizer.show()
# Out:
# <AxesSubplot:title={'center':'Residuals for LinearRegression Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %%
print(f'Mean Absolute Error(MAE): {metrics.mean_absolute_error(y_test, predictions)}')
print(f'\nMean Squared Error(MSE): {metrics.mean_squared_error(y_test, predictions)}')
print(f'\nRoot Mean Square Error(RMSE): {np.sqrt(metrics.mean_squared_error(y_test, predictions))}')
print(f'\nR2 score: {metrics.r2_score(y_test, predictions)}')
# Out:
# Mean Absolute Error(MAE): 12.811861260557523
#
# Mean Squared Error(MSE): 262.2262959770772
#
# Root Mean Square Error(RMSE): 16.19340285354123
#
# R2 score: 0.10078374337405915

# %%
x = dataset[X_columns]
y = dataset['popularity']

# %%
results = sm.OLS(y, x).fit()
print(results.summary())
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             popularity   R-squared (uncentered):                   0.898
# Model:                            OLS   Adj. R-squared (uncentered):              0.898
# Method:                 Least Squares   F-statistic:                              3376.
# Date:                Tue, 04 Oct 2022   Prob (F-statistic):                        0.00
# Time:                        01:17:16   Log-Likelihood:                         -22758.
# No. Observations:                5368   AIC:                                  4.554e+04
# Df Residuals:                    5354   BIC:                                  4.564e+04
# Df Model:                          14
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# artist               0.0014      0.000      3.078      0.002       0.001       0.002
# release_date        -0.2636      0.017    -15.331      0.000      -0.297      -0.230
# duration             0.0196      0.002      9.549      0.000       0.016       0.024
# danceability         0.0235      0.002     11.860      0.000       0.020       0.027
# acousticness         0.0039      0.000      9.889      0.000       0.003       0.005
# energy              -0.0015      0.002     -0.722      0.470      -0.006       0.003
# instrumentalness    -0.0005      0.000     -1.725      0.085      -0.001    6.62e-05
# key                  0.3648      0.066      5.558      0.000       0.236       0.493
# liveness          4.817e-05      0.001      0.049      0.961      -0.002       0.002
# loudness             0.0035      0.000     11.200      0.000       0.003       0.004
# speechiness         -0.0027      0.001     -2.418      0.016      -0.005      -0.001
# tempo                0.0010      0.000      6.170      0.000       0.001       0.001
# time_signature      15.4794      0.711     21.758      0.000      14.085      16.874
# valence             -0.0041      0.001     -3.240      0.001      -0.007      -0.002
# ==============================================================================
# Omnibus:                      209.253   Durbin-Watson:                   1.694
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              236.060
# Skew:                          -0.483   Prob(JB):                     5.50e-52
# Kurtosis:                       3.348   Cond. No.                     1.32e+04
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 1.32e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# &nbsp;

# %% [markdown]
# ## Polynomial basis functions

# %%
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

# %%
X_train_poly, X_test_poly, Y_train_poly, Y_test_poly = train_test_split(X_poly, Y, test_size = 0.2)

# %%
lr.fit(X_train_poly, Y_train_poly)
coeff_lr = pd.DataFrame(lr.coef_, columns=['Coefficient'])
coeff_lr
# Out:
#       Coefficient
# 0   -5.984072e-17
# 1   -1.599444e-01
# 2   -5.615049e+00
# 3    1.560413e+00
# 4    2.515957e+00
# ..            ...
# 115  3.976611e-02
# 116 -4.414244e-01
# 117 -1.114418e-01
# 118  1.590244e-01
# 119  1.043899e-01
#
# [120 rows x 1 columns]

# %%
y_pred = lr.predict(X_test_poly)
plt.figure(figsize=(10,7))
plt.scatter(Y_test_poly, y_pred)
plt.title('Predictions vs Actial')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.show()

# %%
sns.displot((Y_test_poly - y_pred), bins=30, kde=True, color='crimson')
plt.title('Polynomial features degree 2')
plt.show()

# %%
print(f'Mean Absolute Error(MAE): {metrics.mean_absolute_error(Y_test_poly, y_pred)}')
print(f'\nMean Squared Error(MSE): {metrics.mean_squared_error(Y_test_poly, y_pred)}')
print(f'\nRoot Mean Square Error(RMSE): {np.sqrt(metrics.mean_squared_error(Y_test_poly, y_pred))}')
print(f'\nR2 score: {metrics.r2_score(Y_test_poly, y_pred)}')
# Out:
# Mean Absolute Error(MAE): 12.656328061261293
#
# Mean Squared Error(MSE): 259.2156642145716
#
# Root Mean Square Error(RMSE): 16.10017590632387
#
# R2 score: 0.11059728144189795

# %% [markdown]
# &nbsp;

# %% [markdown]
# ## Lasso regression (L1 Regularization)

# %%
lasso = Lasso(alpha=0.05, random_state=0, max_iter=10000)
lasso.fit(X_train, y_train)
# Out:
# Lasso(alpha=0.05, max_iter=10000, random_state=0)

# %%
coeff_lasso = pd.DataFrame(lasso.coef_, X_columns, columns=['Coefficient'])
coeff_lasso
# Out:
#                   Coefficient
# artist              -0.085266
# release_date        -5.381585
# duration             0.798988
# danceability         2.044373
# acousticness        -0.344265
# energy              -1.813187
# instrumentalness    -1.163317
# key                  0.601920
# liveness            -1.300837
# loudness             3.550711
# speechiness         -0.788278
# tempo                0.158600
# time_signature      -0.000000
# valence             -1.164207

# %%
lasso_predicted = lasso.predict(X_test)

# %%
sns.displot((y_test - lasso_predicted), bins=30, kde=True, color='crimson')
plt.title('Lasso Alpha')
plt.show()

# %%
print(f'Mean Absolute Error(MAE): {metrics.mean_absolute_error(y_test, lasso_predicted)}')
print(f'\nMean Squared Error(MSE): {metrics.mean_squared_error(y_test, lasso_predicted)}')
print(f'\nRoot Mean Square Error(RMSE): {np.sqrt(metrics.mean_squared_error(y_test, lasso_predicted))}')
print(f'\nR2 score: {metrics.r2_score(y_test, lasso_predicted)}')
# Out:
# Mean Absolute Error(MAE): 12.804307773682144
#
# Mean Squared Error(MSE): 262.05403694018895
#
# Root Mean Square Error(RMSE): 16.188083176836873
#
# R2 score: 0.10137444739076928

# %%
lasso = Lasso(random_state=0, max_iter=10000)
alphas = np.logspace(-1.5, 1, 30)

parameters = [{'alpha': alphas}]
n_folds = 5

model = GridSearchCV(lasso, parameters, cv=n_folds, refit=False)
model.fit(X_train, y_train)
scores = model.cv_results_['mean_test_score']
scores_std = model.cv_results_['std_test_score']
plt.semilogx(alphas, scores)

std_error = scores_std / np.sqrt(n_folds)

plt.semilogx(alphas, scores + std_error, 'b--')
plt.semilogx(alphas, scores - std_error, 'b--')

plt.fill_between(alphas, scores + std_error, scores - std_error, alpha=0.2)

plt.ylabel('CV score +/- std error')
plt.xlabel('alpha')
plt.axhline(np.max(scores), linestyle='--', color='.5')
plt.xlim([alphas[0], alphas[-1]])
plt.show()

# %% [markdown]
# &nbsp;

# %% [markdown]
# ## Ridge regression (L2 Regularization)

# %%
ridge = Ridge(alpha=62.2, random_state=0, max_iter=10000)
ridge.fit(X_train, y_train)
# Out:
# Ridge(alpha=62.2, max_iter=10000, random_state=0)

# %%
coeff_ridge = pd.DataFrame(ridge.coef_, X_columns, columns=['Coefficient'])
coeff_ridge
# Out:
#                   Coefficient
# artist              -0.127017
# release_date        -5.371751
# duration             0.837457
# danceability         2.111692
# acousticness        -0.428255
# energy              -1.861620
# instrumentalness    -1.216790
# key                  0.642878
# liveness            -1.318921
# loudness             3.550476
# speechiness         -0.823370
# tempo                0.231982
# time_signature      -0.043362
# valence             -1.206247

# %%
ridge_predicted = ridge.predict(X_test)

# %%
sns.displot((y_test - ridge_predicted), bins=30, kde=True, color='crimson')
plt.title('Ridge Alpha')
plt.show()

# %%
print(f'Mean Absolute Error(MAE): {metrics.mean_absolute_error(y_test, ridge_predicted)}')
print(f'\nMean Squared Error(MSE): {metrics.mean_squared_error(y_test, ridge_predicted)}')
print(f'\nRoot Mean Square Error(RMSE): {np.sqrt(metrics.mean_squared_error(y_test, ridge_predicted))}')
print(f'\nR2 score: {metrics.r2_score(y_test, ridge_predicted)}')
# Out:
# Mean Absolute Error(MAE): 12.804556117700088
#
# Mean Squared Error(MSE): 262.16578335953835
#
# Root Mean Square Error(RMSE): 16.191534311470868
#
# R2 score: 0.10099125089812022

# %%
ridge = Ridge(random_state=0, max_iter=10000)
alphas = np.logspace(-0.5, 3, 30)

tuned_parameters = [{'alpha': alphas}]

model = GridSearchCV(ridge, tuned_parameters, cv=n_folds, refit=False)
model.fit(X_train, y_train)
scores = model.cv_results_['mean_test_score']
scores_std = model.cv_results_['std_test_score']
plt.semilogx(alphas, scores)

std_error = scores_std / np.sqrt(n_folds)

plt.semilogx(alphas, scores + std_error, 'b--')
plt.semilogx(alphas, scores - std_error, 'b--')

plt.fill_between(alphas, scores + std_error, scores - std_error, alpha=0.2)

plt.ylabel('CV score Ridge +/- std error')
plt.xlabel('alpha')
plt.axhline(np.max(scores), linestyle='--', color='.5')
plt.xlim([alphas[0], alphas[-1]])
plt.show()

# %% [markdown]
# &nbsp;

# %% [markdown]
# ## Support Vector Regressor (SVR)

# %%
kernels = ['linear', 'rbf', 'poly']

for kernel in kernels:
    regressor = SVR(kernel=kernel, gamma='auto', tol=0.0001, C=0.001, epsilon=0.0001, 
                    shrinking=True, cache_size=200, verbose=False, max_iter=100)
    regressor.fit(X_train, y_train)
    
    y_pred = regressor.predict(X_test)
    
    print(f'Mean Absolute Error(MAE): {metrics.mean_absolute_error(y_test, y_pred)}')
    print(f'Mean Squared Error(MSE): {metrics.mean_squared_error(y_test, y_pred)}')
    print(f'Root Mean Square Error(RMSE): {np.sqrt(metrics.mean_squared_error(y_test, y_pred))}')
    print(f'R2: {metrics.r2_score(y_test, y_pred)}\n')
# Out:
# Mean Absolute Error(MAE): 17.225494948931747
# Mean Squared Error(MSE): 418.1261222123319
# Root Mean Square Error(RMSE): 20.448132487157157
# R2: -0.4338219018513725
#
# Mean Absolute Error(MAE): 17.22302761089804
# Mean Squared Error(MSE): 418.1054363553388
# Root Mean Square Error(RMSE): 20.447626668035067
# R2: -0.4337509667118544
#
# Mean Absolute Error(MAE): 17.224122458250566
# Mean Squared Error(MSE): 418.1500607231665
# Root Mean Square Error(RMSE): 20.448717825897216
# R2: -0.43390399086544984

# %% [markdown]
# &nbsp;

# %% [markdown]
# ## KNN

# %%
knn = KNeighborsRegressor()
knn.fit(X_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
knn_predictions = knn.predict(X_test)

# %%
plt.scatter(y_test, knn_predictions)
plt.axis('square')
plt.show()

# %%
print(f'Mean Absolute Error(MAE): {metrics.mean_absolute_error(y_test, knn_predictions)}')
print(f'Mean Squared Error(MSE): {metrics.mean_squared_error(y_test, knn_predictions)}')
print(f'Root Mean Square Error(RMSE): {np.sqrt(metrics.mean_squared_error(y_test, knn_predictions))}')
print(f'R2: {metrics.r2_score(y_test, knn_predictions)}')
# Out:
# Mean Absolute Error(MAE): 13.810800744878957
# Mean Squared Error(MSE): 309.0472253258846
# Root Mean Square Error(RMSE): 17.579739057388895
# R2: -0.05977277390391289
