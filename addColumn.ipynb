# %%
import pandas as pd

# %%
dataset=pd.read_csv("history-of-rock-spotify.csv")

# %%
dataset['hit'] = ''

# %%
dataset.head()
# Out:
#    Unnamed: 0  index                                          name  \
# 0           0      0                       Smells Like Teen Spirit
# 1           1      1                 Stairway to Heaven - Remaster
# 2           2      2           Bohemian Rhapsody - Remastered 2011
# 3           3      3                     Imagine - Remastered 2010
# 4           4      4  (I Can't Get No) Satisfaction - Mono Version
#
#                artist  release_date    length  popularity  danceability  \
# 0             Nirvana          1991  5.032000          74         0.502
# 1        Led Zeppelin          1971  8.047167          78         0.338
# 2               Queen          1975  5.905333          74         0.392
# 3         John Lennon          1971  3.131100          77         0.547
# 4  The Rolling Stones          1965  3.713550          77         0.723
#
#    acousticness  danceability.1  energy  instrumentalness  key  liveness  \
# ...

# %%
dataset.popularity
# Out:
# 0       74
# 1       78
# 2       74
# 3       77
# 4       77
#         ..
# 5479    47
# 5480    44
# 5481    40
# 5482    52
# 5483     0
# Name: popularity, Length: 5484, dtype: int64

# %%
dataset.loc[dataset.popularity <= 50, "hit"] = '0'

# %%
dataset.loc[dataset.popularity > 50, "hit"] = '1'

# %%
dataset
# Out:
#       Unnamed: 0  index                                          name  \
# 0              0      0                       Smells Like Teen Spirit
# 1              1      1                 Stairway to Heaven - Remaster
# 2              2      2           Bohemian Rhapsody - Remastered 2011
# 3              3      3                     Imagine - Remastered 2010
# 4              4      4  (I Can't Get No) Satisfaction - Mono Version
# ...          ...    ...                                           ...
# 5479        5479   5479                              I'm In Your Mind
# 5480        5480   5480                                    Cellophane
# 5481        5481   5481                                     Hot Water
# 5482        5482   5482           Vitamin C - 2004 Remastered Version
# 5483        5483   5483                                             ~
#
#                                 artist  release_date    length  popularity  \
# ...

# %%
dataset.drop(['Unnamed: 0', 'index', 'danceability.1'], axis=1, inplace = True)

# %%
dataset.to_csv('history-of-rock-spotify.csv')

# %%
dataset
# Out:
#                                               name  \
# 0                          Smells Like Teen Spirit
# 1                    Stairway to Heaven - Remaster
# 2              Bohemian Rhapsody - Remastered 2011
# 3                        Imagine - Remastered 2010
# 4     (I Can't Get No) Satisfaction - Mono Version
# ...                                            ...
# 5479                              I'm In Your Mind
# 5480                                    Cellophane
# 5481                                     Hot Water
# 5482           Vitamin C - 2004 Remastered Version
# 5483                                             ~
#
#                                 artist  release_date    length  popularity  \
# 0                              Nirvana          1991  5.032000          74
# 1                         Led Zeppelin          1971  8.047167          78
# 2                                Queen          1975  5.905333          74
# ...
